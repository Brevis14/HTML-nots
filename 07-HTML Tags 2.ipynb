# %% [markdown]
# ### 1️⃣ Table Tag: `<table>`-`<tr>`-`<td>`
# Basic Syntax:
# [![2025-08-27-094114.png](https://i.postimg.cc/QMq2FMw5/2025-08-27-094114.png)](https://postimg.cc/Y4hnVtpq)
#
# ### 2️⃣ Table Header Cell Tag: `<th>`
# A table header cell is also a type of cell, but it is displayed centered and bold.
#
# [![2025-08-27-094834.png](https://i.postimg.cc/QxbYgz0G/2025-08-27-094834.png)](https://postimg.cc/w71kg0C0)
#
# ### 3️⃣ Table Attributes
# [![2025-08-27-095310.png](https://i.postimg.cc/g2hXFC51/2025-08-27-095310.png)](https://postimg.cc/LJH6jbmV)
#
# ### 4️⃣ Table Structure Tags
# [![2025-08-27-100228.png](https://i.postimg.cc/Qth0Wk1x/2025-08-27-100228.png)](https://postimg.cc/FfCjMST2)
#
# ### 5️⃣ Merge Cells
# [![2025-08-27-100536.png](https://i.postimg.cc/prgjKR4Y/2025-08-27-100536.png)](https://postimg.cc/jn4Cb0sL)
# Selection of the Target Cell(s):
#
# [![2025-08-27-100801.png](https://i.postimg.cc/43dzCL6c/2025-08-27-100801.png)](https://postimg.cc/mPvcCS6Z)
# Three Steps:
#
# [![2025-08-27-100944.png](https://i.postimg.cc/V69Mnx13/2025-08-27-100944.png)](https://postimg.cc/ftLJhgVK)
#
# ### 6️⃣ List Tag:
# [![2025-08-27-101236.png](https://i.postimg.cc/RC6qrrj9/2025-08-27-101236.png)](https://postimg.cc/Sj4m8PSt)
# #### Unordered List: `<ul>`-`<li>`
# [![2025-08-27-101559.png](https://i.postimg.cc/c4hpXCXJ/2025-08-27-101559.png)](https://postimg.cc/bsGVvyXX)
# #### Ordered List: `<ol>`-`<li>`
# [![2025-08-27-103912.png](https://i.postimg.cc/Y2GTBkMp/2025-08-27-103912.png)](https://postimg.cc/23Y0ns1J)
# #### Definition List: `<dl>`-`<dt>`-`<dd>`
# [![2025-08-27-104339.png](https://i.postimg.cc/nhbJPrmb/2025-08-27-104339.png)](https://postimg.cc/HV2RJp3B)
#
# ### 7️⃣ Form Tag:
# [![2025-08-27-104609.png](https://i.postimg.cc/1z41gFhF/2025-08-27-104609.png)](https://postimg.cc/R3rDyN0C)
# #### Form Field: `<form>`
# [![2025-08-27-104928.png](https://i.postimg.cc/fLjCDH2f/2025-08-27-104928.png)](https://postimg.cc/WFzg77Pd)
# #### Form Controls (Form Elements)
# [![2025-08-27-112821.png](https://i.postimg.cc/904Qhk1D/2025-08-27-112821.png)](https://postimg.cc/rRkkGQBT)
# ##### `<input>`
# [![2025-08-27-112938.png](https://i.postimg.cc/jdPJnWQL/2025-08-27-112938.png)](https://postimg.cc/7fPLpZRk)
# [![2025-08-27-112957.png](https://i.postimg.cc/kgCRQnfw/2025-08-27-112957.png)](https://postimg.cc/dLW0vKMT)
# Note: "name" is the name of a form element. To implement multiple radio buttons for single selection (only one can be chosen), you need to set the same "name" attribute for them.
#
# [![2025-08-27-114425.png](https://i.postimg.cc/3r6cJqn3/2025-08-27-114425.png)](https://postimg.cc/xqvR6twZ)
#
# One episode titled "Input's type Attribute: Regular Buttons and File Input Fields" is missing.
# ###### Label Tag: `<label>`
# [![2025-08-27-134703.png](https://i.postimg.cc/htks7CjT/2025-08-27-134703.png)](https://postimg.cc/cvcwpBfL)
# ##### `<select>`
# [![2025-08-27-135009.png](https://i.postimg.cc/FHN3t27P/2025-08-27-135009.png)](https://postimg.cc/YhDhYDNg)
#
# ##### `<textarea>`
# [![2025-08-27-135542.png](https://i.postimg.cc/HLGGs91P/2025-08-27-135542.png)](https://postimg.cc/CR4rcD1j)
